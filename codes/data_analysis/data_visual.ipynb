# %%
import pandas as pd
data_1 = pd.read_csv(r'C:\Users\Jiang Bing Han\Nature language processing and text anylsis\tic_rev_ind.csv',engine='python')
data_2 = pd.read_csv(r'C:\Users\Jiang Bing Han\Nature language processing and text anylsis\aim_ticker.csv',engine='python')

# %%
gsub_aim_ticker=data_1[data_1['gsubind']==20304020]
g_list=aim_ticker['tic'].tolist()
k_list = data_2['k_ticker'].dropna().tolist()
e_list = data_2['E_ticker'].dropna().tolist()
s_list = data_2['S_ticker'].dropna().tolist()

# %%
print(len(g_list))
print(len(k_list))
print(len(e_list))
print(len(s_list))
# Out:
# 18
# 42
# 15
# 30

# %%
list(set(g_list).intersection(k_list))
# Out:
# ['XPO', 'YELL', 'JBHT', 'PTSI', 'ODFL']

# %%
list(set(g_list).intersection(e_list))
# Out:
# ['MRTN', 'XPO', 'YELL', 'DSKE', 'JBHT', 'PTSI', 'ODFL']

# %%
list(set(g_list).intersection(s_list))
# Out:
# ['XPO', 'MRTN', 'HTLD', 'DSKE', 'USAK', 'PTSI']

# %%
list(set(k_list).intersection(e_list))
# Out:
# ['XPO',
#  'MATX',
#  'MLR',
#  'EVOA',
#  'YELL',
#  'SNDR',
#  'FWRD',
#  'HUBG',
#  'JBHT',
#  'PTSI',
#  'ODFL']

# %%
list(set(k_list).intersection(s_list))
# Out:
# ['XPO', 'UPS', 'ISSC', 'HII', 'CARR', 'SNDR', 'SHEN', 'PTSI']

# %%
list(set(e_list).intersection(s_list))
# Out:
# ['XPO', 'MRTN', 'SNDR', 'DSKE', 'PTSI']

# %%
list(set(k_list).intersection(e_list,s_list))
# Out:
# ['XPO', 'SNDR', 'PTSI']

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
from matplotlib_venn import venn2
venn3([set(e_list), set(k_list),set(s_list)],set_labels = ('Euclidean', 'K-means','Som'));

# %%
venn3([set(g_list), set(k_list),set(s_list)],set_labels = ('gsubind', 'K-means','Som'));

# %%
venn2([set(g_list), set(e_list)],set_labels = ('gsubind', 'Euclidean'));

# %%
venn3([set(e_list), set(k_list),set(g_list)],set_labels = ('Euclidean', 'K-means','gsubind'));

# %%
venn2([set(s_list),set(g_list)],set_labels = ('som','gsubind'));

# %%
list(set(s_list).difference(set(g_list)))
# Out:
# ['WERN',
#  'ARNC',
#  'CARR',
#  'TDY',
#  'MOG-A',
#  'WWD',
#  'HWM',
#  'INT',
#  'HII',
#  'CW',
#  'TDG',
#  'AIN',
#  'ATNI',
#  'ISSC',
#  'B',
#  'UAVS',
#  'SNDR',
#  'AIRI',
#  'CNSL',
#  'UPS',
#  'CHRW',
#  'CR',
#  'KAMN',
#  'SHEN']
